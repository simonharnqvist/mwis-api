# %%
from mwis_api.mwis_scraper.scrape import get_regions, get_forecast_html
from mwis_api.mwis_scraper.scrape import Region

# %%
soup = get_forecast_html("scottish", "southern-uplands")

# %%
soup.find("title").text == "Southern Uplands Forecast"
# Out:
# True
